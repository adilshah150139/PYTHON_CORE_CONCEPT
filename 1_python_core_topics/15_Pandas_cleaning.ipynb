# %%
import pandas as pd
from datasets import load_dataset


dataset = load_dataset('lukebarousse/data_jobs')
dataset

# %%
df = dataset['train'].to_pandas()
df.head()

# %%
date_posted = df.job_posted_date
type(date_posted[0])

# %%
df.shape

# %%
# Using dropna(), will drop out those rows that have Null values
df.dropna(subset=['salary_year_avg'], inplace = True) # Using inplace, it also change the original df

# %%
df.shape

# %%
df.drop(columns= ['salary_hour_avg'], inplace= True)

# %%
display(df.sort_index())

# %%
df.info()   # salary_hour_avg drop out form original df as well

# %%
# ============================================================
# 📊 CELL 8: SUMMARY
# ============================================================

print("=" * 60)
print("7️⃣ SUMMARY - KEY TAKEAWAYS")
print("=" * 60)

print("""
📌 DROPNA:
   → Removes rows with missing (NaN) values
   → Keeps all columns
   → Use when: Cleaning data

📌 DROP:
   → Removes specific rows or columns
   → You decide exactly what to remove
   → Use when: Removing specific data

📌 INPLACE:
   → inplace=False (default): Creates a NEW DataFrame
   → inplace=True: Modifies the ORIGINAL DataFrame
   → Use inplace=True when you don't need the original

📌 AXIS:
   → axis=0 (default): Rows
   → axis=1: Columns
""")

print("=" * 60)
print("🎉 REVISION COMPLETE!")
print("=" * 60)
